# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('F:\Data_Science\Diabetes\Diabetes.csv')

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.count()
# Out:
# Pregnancies                 2000
# Glucose                     2000
# BloodPressure               2000
# SkinThickness               2000
# Insulin                     2000
# BMI                         2000
# DiabetesPedigreeFunction    2000
# Age                         2000
# Outcome                     2000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.heatmap(df.isna())

# %%
df.nunique().sort_values()
# Out:
# Outcome                       2
# Pregnancies                  17
# BloodPressure                47
# Age                          52
# SkinThickness                53
# Glucose                     136
# Insulin                     182
# BMI                         247
# DiabetesPedigreeFunction    505
# dtype: int64

# %%
plt.figure(figsize=(6,6))
df.nunique().sort_values().plot(kind='barh', alpha=0.8, color='r')
plt.ylabel('Feartures',color='b',fontsize='large') 
plt.xlabel('No of Unique Features',color='b',fontsize='large')
plt.yticks(fontsize='large')
plt.xticks(fontsize='large')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df['Outcome'].value_counts()
# Out:
# 0    1316
# 1     684
# Name: Outcome, dtype: int64

# %%
bins=[-1,0,1]
labels=['No Diabetes','Diabetes']
df['Outcome']=pd.cut(df['Outcome'],bins=bins,labels=labels)

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age      Outcome
# 0                        0.127   47     Diabetes
# ...

# %%
df['Glucose']=np.where(df['Glucose']==0,df['Glucose'].median(),df['Glucose'])
df['Insulin']=np.where(df['Insulin']==0,df['Insulin'].median(),df['Insulin'])
df['SkinThickness']=np.where(df['SkinThickness']==0,df['SkinThickness'].median(),df['SkinThickness'])

# %%
sns.countplot(df['Outcome'],data=df)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
sns.catplot(x='Outcome',y='Glucose',data=df,kind='boxen',palette='Set2')
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen".

# %%
sns.relplot(x='BloodPressure',y='Glucose',hue='Outcome',data=df,palette='Set1')
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen".

# %%
sns.relplot(x='Age',y='Glucose',hue='Outcome',data=df,palette='Set2')
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen".

# %%
sns.relplot(x='Age',y='BloodPressure',hue='Outcome',data=df,palette='Set1')
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen".

# %%
sns.relplot(x='BMI',y='Glucose',hue='Outcome',data=df,palette='magma')
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen".

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df.corr(), annot = True, cmap = "RdYlGn")
plt.show()

# %%
X=df.loc[:,~(df.columns=='Outcome')]

# %%
y=df.iloc[:,-1]

# %%
X
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2    138.0             62           35.0     40.0  33.6
# 1               0     84.0             82           31.0    125.0  38.2
# 2               0    145.0              0           23.0     40.0  44.2
# 3               0    135.0             68           42.0    250.0  42.3
# 4               1    139.0             62           41.0    480.0  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2     75.0             64           24.0     55.0  29.7
# 1996            8    179.0             72           42.0    130.0  32.7
# 1997            6     85.0             78           23.0     40.0  31.2
# 1998            0    129.0            110           46.0    130.0  67.1
# 1999            2     81.0             72           15.0     76.0  30.1
#
#       DiabetesPedigreeFunction  Age
# 0                        0.127   47
# ...

# %%
y
# Out:
# 0          Diabetes
# 1       No Diabetes
# 2          Diabetes
# 3          Diabetes
# 4       No Diabetes
#            ...
# 1995    No Diabetes
# 1996       Diabetes
# 1997    No Diabetes
# 1998       Diabetes
# 1999    No Diabetes
# Name: Outcome, Length: 2000, dtype: category
# Categories (2, object): [No Diabetes < Diabetes]

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesClassifier
selection = ExtraTreesClassifier()
selection.fit(X, y)
# Out:
# ExtraTreesClassifier()

# %%
print(selection.feature_importances_)
# Out:
# [0.10361835 0.24589754 0.10138099 0.08082222 0.07687774 0.13568391
#  0.11413093 0.14158832]

# %%
plt.figure(figsize=(15,10))
feature_imp=pd.Series(selection.feature_importances_, index=X.columns)
feature_imp.nlargest(14).plot(kind='barh')

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=10)

# %%
s=StandardScaler()
X_train=s.fit_transform(X_train)
X_test=s.transform(X_test)

# %%
svmodel=SVC()
svmodel.fit(X_train,y_train)
svmodel.score(X_test,y_test)
# Out:
# 0.834

# %%
value=[]
algo=[]
def cross_val_score_model(model,name):
    cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=10)
    cv_score=cross_val_score(model,X,y,cv=cv).mean()
    print('CV_Score' + ' '+ str(model) +': '+ str(cv_score))
    value.append(cv_score)
    algo.append(name)

cross_val_score_model(SVC(),'SVC')
cross_val_score_model(RandomForestClassifier(),'Random Forest Classifier')
cross_val_score_model(XGBClassifier(),'XGB Classifier')
cross_val_score_model(KNeighborsClassifier(),'KNeighbors Classifier')
cross_val_score_model(DecisionTreeClassifier(),'DecisionTree Classifier')
cross_val_score_model(LogisticRegression(solver='liblinear',multi_class='auto'),'Logistic Regression')
# Out:
# CV_Score SVC(): 0.782
# CV_Score RandomForestClassifier(): 0.9724
# CV_Score XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None): 0.966
# CV_Score KNeighborsClassifier(): 0.7932
# CV_Score DecisionTreeClassifier(): 0.9635999999999999
# CV_Score LogisticRegression(solver='liblinear'): 0.7832000000000001

# %%
sns.barplot(x=value,y=algo)
plt.show()

# %%
model_params={
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[100,200,500],
            'criterion' : ['gini', 'entropy'],
            'max_features' : ['auto', 'sqrt'],
            'max_depth' : [5,10,15,20,25,30,35,40,45,50]
        }
    },
        'XGBoost':{
        'model':XGBClassifier(),
        'params':{
            'booster':['gbtree','gblinear'],
            'learning_rate':[0.05,0.1,0.15,0.20]
        }
    },
    'Decision Tree Classifier':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion' : ['gini', 'entropy'],
            'max_depth' : [5,10,15,20,25,30,35,40,45,50],
            'splitter':['best','random']

        }
    }
}

# %%
scores=[]
cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=10)
for model_name, mp in model_params.items():
    random_clf=RandomizedSearchCV(mp['model'],mp['params'],cv=cv, return_train_score=False)
    random_clf.fit(X,y)
    scores.append({
        'model':model_name,
        'best_score':random_clf.best_score_,
        'best param':random_clf.best_params_,
        'best estimator':random_clf.best_estimator_
    })

ds=pd.DataFrame(scores,columns=['model','best_score','best param','best estimator'])
ds
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
#                       model  best_score  \
# 0             random_forest      0.9724
# 1                   XGBoost      0.9672
# 2  Decision Tree Classifier      0.9648
#
#                                           best param  \
# 0  {'n_estimators': 100, 'max_features': 'auto', ...
# 1        {'learning_rate': 0.2, 'booster': 'gbtree'}
# 2  {'splitter': 'random', 'max_depth': 45, 'crite...
#
#                                       best estimator
# 0  (DecisionTreeClassifier(max_depth=40, max_feat...
# 1  XGBClassifier(base_score=0.5, booster='gbtree'...
# 2  DecisionTreeClassifier(max_depth=45, splitter=...

# %%
def display_text_max_col_width(df, width):
    with pd.option_context('display.max_colwidth', width):
        print(df)

display_text_max_col_width(ds['best param'], 800)
# Out:
# 0    {'n_estimators': 100, 'max_features': 'auto', 'max_depth': 40, 'criterion': 'gini'}
# 1                                            {'learning_rate': 0.2, 'booster': 'gbtree'}
# 2                           {'splitter': 'random', 'max_depth': 45, 'criterion': 'gini'}
# Name: best param, dtype: object

# %%
cross_val_score_model(RandomForestClassifier(n_estimators= 100,criterion='gini',max_features= 'auto', max_depth= 40),'Random Forest Classifier_Best')
cross_val_score_model(XGBClassifier(learning_rate= 0.2, booster= 'gbtree'),'XGB Classifier_Best')
cross_val_score_model(DecisionTreeClassifier(splitter='random', max_depth=45, criterion='gini'),'DecisionTree Classifier_best')
# Out:
# CV_Score RandomForestClassifier(max_depth=40): 0.974
# CV_Score XGBClassifier(base_score=None, booster='gbtree', colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=0.2, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None): 0.9672000000000001
# CV_Score DecisionTreeClassifier(max_depth=45, splitter='random'): 0.9640000000000001

# %%
sns.barplot(x=value,y=algo)
plt.xlabel('Cross_Val_Score')
plt.ylabel('Model')
plt.show()

# %%
#Best mode: RfRegressor with HyperParameter Optimization

# %%
from sklearn.metrics import accuracy_score
rf_clas=RandomForestClassifier()
rf_clas.fit(X_train,y_train)
rf_y_pred=rf_clas.predict(X_test)
accuracy=accuracy_score(y_test,rf_y_pred)
accuracy
# Out:
# 0.962

# %%
rf_clas_best=RandomForestClassifier(n_estimators= 100,criterion='gini',max_features= 'auto', max_depth= 40)
rf_clas_best.fit(X_train,y_train)
rf_best_y_pred=rf_clas_best.predict(X_test)
accuracy1=accuracy_score(y_test,rf_best_y_pred)
accuracy1
# Out:
# 0.974

# %%
df.iloc[101]
# Out:
# Pregnancies                           1
# Glucose                             151
# BloodPressure                        60
# SkinThickness                        23
# Insulin                              40
# BMI                                26.1
# DiabetesPedigreeFunction          0.179
# Age                                  22
# Outcome                     No Diabetes
# Name: 101, dtype: object

# %%
a=[[1,151,60,0,0,26.1,0.179,22]]
a=s.transform(a)
b=rf_clas_best.predict(a)
b
# Out:
# array(['No Diabetes'], dtype=object)
